# %%
from utils.Utils import get_ds_from_ceda
import numpy as np
import xarray as xr
import os
import glob
import matplotlib.pyplot as plt
import pandas as pd
import json
import cftime
from cftime import DatetimeNoLeap
from scipy import stats
from scipy.interpolate import interp1d
import dask
from tqdm import tqdm
#from mpl_axes_aligner import align
from xmip.preprocessing import rename_cmip6
# %matplotlib inline
#import xesmf as xe
import matplotlib
from utils import QACC_utils
#from utils.config import model, min_lat, max_lat, min_year_late_cent, max_year_late_cent
##### SETTINGS
model = 'UKESM1-0-LL'
regions = ['Arctic', 'Tropics']
lat_band_dict = {'Arctic':[66, 90],
                 'Tropics':[-23, 23]}
scenarios = ['ssp245', 'ARISE', 'ssp245_baseline']
experiment_dict = {'ssp245':'ssp245', 
                   'ARISE':'ARISE',
                   'ssp245_baseline':'ssp245'}
time_slice_dict = {'ssp245':['2050', '2070'], 
                   'ARISE':['2050', '2070'],
                   'ssp245_baseline':['2015', '2030']}

# %%
os.listdir('/badc/deposited2022/arise/data/ARISE/MOHC/UKESM1-0-LL/arise-sai-1p5/r1i1p1f2/Omon/')
# Out:
# ['agessc',
#  'bfeos',
#  'bsios',
#  'cfc11',
#  'cfc12',
#  'chl',
#  'chldiatos',
#  'chlmiscos',
#  'chlos',
#  'co3',
#  'co3satarag',
#  'co3satcalc',
#  'detoc',
#  'dfe',
#  'dfeos',
#  'dissic',
#  'dpco2',
#  'epc100',
#  'epcalc100',
#  'epfe100',
#  'epn100',
#  'epp100',
#  'epsi100',
#  'evs',
#  'expc',
#  'fbddtdic',
#  'fddtalk',
#  'fddtdic',
#  'fgcfc11',
#  'fgcfc12',
#  'fgco2',
#  'fgdms',
#  'fgo2',
#  'fgsf6',
#  'ficeberg',
#  'fric',
#  'friver',
#  'froc',
#  'fsfe',
#  'hfbasin',
#  'hfbasinpadv',
#  'hfbasinpmadv',
#  'hfbasinpmdiff',
#  'hfds',
#  'hfevapds',
#  'hfibthermds',
#  'hfrainds',
#  'hfrunoffds',
#  'hfx',
#  'hfy',
#  'htovgyre',
#  'htovovrt',
#  'intdic',
#  'intpbfe',
#  'intpbsi',
#  'intpcalcite',
#  'intpoc',
#  'intpp',
#  'intppdiat',
#  'intppmisc',
#  'limfediat',
#  'limfemisc',
#  'limirrdiat',
#  'limirrmisc',
#  'limndiat',
#  'limnmisc',
#  'masscello',
#  'masso',
#  'mlotst',
#  'mlotstmax',
#  'mlotstmin',
#  'mlotstsq',
#  'msftbarot',
#  'msftyz',
#  'msftyzmpa',
#  'no3',
#  'no3os',
#  'o2',
#  'o2os',
#  'o2sat',
#  'o2satos',
#  'obvfsq',
#  'pbo',
#  'ph',
#  'phos',
#  'phyc',
#  'phycos',
#  'phynos',
#  'phypos',
#  'po4',
#  'ponos',
#  'popos',
#  'prra',
#  'prsn',
#  'rsdo',
#  'sf6',
#  'si',
#  'sios',
#  'sltovgyre',
#  'sltovovrt',
#  'so',
#  'sob',
#  'soga',
#  'sos',
#  'sosga',
#  'spco2',
#  'talk',
#  'tauuo',
#  'tauvo',
#  'thetao',
#  'thetaoga',
#  'thkcello',
#  'tob',
#  'tos',
#  'tosga',
#  'tossq',
#  'umo',
#  'uo',
#  'vmo',
#  'vo',
#  'volo',
#  'wfo',
#  'wmo',
#  'wo',
#  'zfullo',
#  'zmicro',
#  'zooc',
#  'zos',
#  'zossq',
#  'zostoga',
#  'zsatarag',
#  'zsatcalc']
